# %% [markdown]
# <a href="https://colab.research.google.com/github/mterezacf/portifolio/blob/main/JogodaVelhaTrabalho.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## -----------------------------------------------------
#    Projeto: Jogo da Velha
#    Disciplina: Lógica de Programação
#    Participantes: Maria Tereza Constantino Ferreira / Wellington Lopes Oliveira / Mareuza da Silva de Oliveira / Matheus Messias / José Damazio Ferreira Filho
## -----------------------------------------------------


def criaMatriz():
    mat = [
        [1, 2, 3],
        [4, 5, 6],
        [7, 8, 9]
    ]
    return mat

def posicaoOcupada(matriz, posicao):

    for linha in matriz:
        if posicao in linha:
            return False
    return True

def registraJogada(mat, posicao, jogador):

    for i in range(len(mat)):
        for j in range(len(mat[i])):
            if mat[i][j] == posicao:
                mat[i][j] = jogador
    return mat

def apresentaMatriz(mat):
    print(mat[0][0], "|", mat[0][1], "|", mat[0][2])
    print("-" * 10)
    print(mat[1][0], "|", mat[1][1], "|", mat[1][2])
    print("-" * 10)
    print(mat[2][0], "|", mat[2][1], "|", mat[2][2])

def trocaJogador(jogador):

    if jogador == "X":
        return "O"
    else:
        return "X"

def verificaGanhador(mat, jogador):

    for i in range(len(mat)):

        if mat[i][0] == mat[i][1] == mat[i][2] == jogador:
            return True

        if mat[0][i] == mat[1][i] == mat[2][i] == jogador:
            return True

    if mat[0][0] == mat[1][1] == mat[2][2] == jogador or mat[0][2] == mat[1][1] == mat[2][0] == jogador:
        return True
    return False


print("*** JOGO DA VELHA *** \n")
print("Desafie o seu colega no jogo da velha.\n")
print("Regras:")
print("a) O primeiro jogador participará com a letra X e o segundo com a letra O.")
print("b) Os números de 1 a 9 representam os espaços que estão livres.")
print("c) Você só poderá escolher as posições livres.")
print("d) O vencedor será o primeiro jogador a preencher uma linha, uma coluna ou uma diagonal.")

matriz = criaMatriz()
jogador = "X"
c = 0
while c < 9:
    apresentaMatriz(matriz)
    posicao = int(input(f"(Jogador {jogador}) Informe a posição desejada: "))

    if posicaoOcupada(matriz, posicao):
        print("\nVocê não pode escolher uma posição que já está ocupada. Tente novamente.")
        continue
    else:
        matriz = registraJogada(matriz, posicao, jogador)
        if verificaGanhador(matriz, jogador):
            print(f"\nO jogador {jogador} venceu!")
            break
        jogador = trocaJogador(jogador)
    c += 1

if c == 9:
    print("\nO jogo empatou!")

print("Fim de jogo.")
# Out:
# *** JOGO DA VELHA ***
#
# Desafie o seu colega no jogo da velha.
#
# Regras:
# a) O primeiro jogador participará com a letra X e o segundo com a letra O.
# b) Os números de 1 a 9 representam os espaços que estão livres.
# c) Você só poderá escolher as posições livres.
# d) O vencedor será o primeiro jogador a preencher uma linha, uma coluna ou uma diagonal.
# 1 | 2 | 3
# ----------
# 4 | 5 | 6
# ----------
# 7 | 8 | 9
# (Jogador X) Informe a posição desejada: 3
# 1 | 2 | X
# ----------
# 4 | 5 | 6
# ----------
# 7 | 8 | 9
# (Jogador O) Informe a posição desejada: 6
# 1 | 2 | X
# ----------
# 4 | 5 | O
# ----------
# 7 | 8 | 9
# (Jogador X) Informe a posição desejada: 5
# 1 | 2 | X
# ----------
# 4 | X | O
# ----------
# 7 | 8 | 9
# (Jogador O) Informe a posição desejada: 8
# 1 | 2 | X
# ----------
# 4 | X | O
# ----------
# 7 | O | 9
# (Jogador X) Informe a posição desejada: 7
#
# O jogador X venceu!
# Fim de jogo.
